# %%
import pandas as pd 
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
import requests 

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e9c8a2fb328204dceb36147d93ecc6b6&q=Boston

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ilulissat
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | sola
# Processing Record 6 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | kruisfontein
# Processing Record 9 of Set 1 | huejuquilla el alto
# Processing Record 10 of Set 1 | bozoum
# Processing Record 11 of Set 1 | freeport
# Processing Record 12 of Set 1 | yulara
# Processing Record 13 of Set 1 | diapaga
# Processing Record 14 of Set 1 | half moon bay
# Processing Record 15 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | talnakh
# Processing Record 18 of Set 1 | duiwelskloof
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | naze
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | codrington
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | kayerkan
# Processing Record 28 of Set 1 | tanete
# Processing Record 29 of Set 1 | tilichiki
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | chicama
# Processing Record 33 of Set 1 | kaupanger
# Processing Record 34 of Set 1 | panguna
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | torbay
# Processing Record 37 of Set 1 | katsuura
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | hasaki
# Processing Record 40 of Set 1 | waddan
# Processing Record 41 of Set 1 | kalmunai
# Processing Record 42 of Set 1 | turukhansk
# Processing Record 43 of Set 1 | pavlodar
# Processing Record 44 of Set 1 | morris
# Processing Record 45 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 1 | obzor
# Processing Record 47 of Set 1 | nanortalik
# Processing Record 48 of Set 1 | lodja
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | ajdabiya
# Processing Record 1 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 2 | pahrump
# Processing Record 3 of Set 2 | muravlenko
# Processing Record 4 of Set 2 | mount isa
# Processing Record 5 of Set 2 | cherskiy
# Processing Record 6 of Set 2 | pinega
# Processing Record 7 of Set 2 | samarai
# Processing Record 8 of Set 2 | batagay-alyta
# Processing Record 9 of Set 2 | caravelas
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 2 | palmer
# Processing Record 13 of Set 2 | boyolangu
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | russell
# Processing Record 17 of Set 2 | shimoda
# Processing Record 18 of Set 2 | egvekinot
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | virginia beach
# Processing Record 21 of Set 2 | neiafu
# Processing Record 22 of Set 2 | severodvinsk
# Processing Record 23 of Set 2 | maumere
# Processing Record 24 of Set 2 | east london
# Processing Record 25 of Set 2 | faanui
# Processing Record 26 of Set 2 | serebryanyy bor
# Processing Record 27 of Set 2 | manerbio
# Processing Record 28 of Set 2 | merauke
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | kamina
# Processing Record 31 of Set 2 | thompson
# Processing Record 32 of Set 2 | haines junction
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | bilibino
# Processing Record 35 of Set 2 | sazonovo
# Processing Record 36 of Set 2 | thanatpin
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | moose factory
# Processing Record 39 of Set 2 | nagato
# Processing Record 40 of Set 2 | vila velha
# Processing Record 41 of Set 2 | bouca
# Processing Record 42 of Set 2 | launceston
# Processing Record 43 of Set 2 | gamba
# Processing Record 44 of Set 2 | asilah
# Processing Record 45 of Set 2 | zhigansk
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | svetlyy
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | saint-francois
# Processing Record 1 of Set 3 | olga
# Processing Record 2 of Set 3 | tutoia
# Processing Record 3 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 3 | xingcheng
# Processing Record 5 of Set 3 | salalah
# Processing Record 6 of Set 3 | cartagena
# Processing Record 7 of Set 3 | longyearbyen
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | coihaique
# Processing Record 10 of Set 3 | bluff
# Processing Record 11 of Set 3 | ostrovnoy
# Processing Record 12 of Set 3 | gushikawa
# Processing Record 13 of Set 3 | gbadolite
# Processing Record 14 of Set 3 | dikson
# Processing Record 15 of Set 3 | mehamn
# Processing Record 16 of Set 3 | mataura
# Processing Record 17 of Set 3 | mayo
# Processing Record 18 of Set 3 | lompoc
# Processing Record 19 of Set 3 | cabras
# Processing Record 20 of Set 3 | taoudenni
# Processing Record 21 of Set 3 | kavieng
# Processing Record 22 of Set 3 | les trois-ilets
# Processing Record 23 of Set 3 | ino
# Processing Record 24 of Set 3 | riyadh
# Processing Record 25 of Set 3 | dingle
# Processing Record 26 of Set 3 | sorong
# Processing Record 27 of Set 3 | parkes
# Processing Record 28 of Set 3 | dalbandin
# Processing Record 29 of Set 3 | tucuman
# Processing Record 30 of Set 3 | kapaa
# Processing Record 31 of Set 3 | iqaluit
# Processing Record 32 of Set 3 | shenjiamen
# Processing Record 33 of Set 3 | atuona
# Processing Record 34 of Set 3 | pemangkat
# Processing Record 35 of Set 3 | chabahar
# Processing Record 36 of Set 3 | kenai
# Processing Record 37 of Set 3 | palembang
# Processing Record 38 of Set 3 | butaritari
# Processing Record 39 of Set 3 | verkhovazhye
# Processing Record 40 of Set 3 | hambantota
# Processing Record 41 of Set 3 | hamilton
# Processing Record 42 of Set 3 | sofiysk
# City not found. Skipping...
# Processing Record 43 of Set 3 | villa carlos paz
# Processing Record 44 of Set 3 | sitka
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | pyinmana
# Processing Record 47 of Set 3 | sambava
# Processing Record 48 of Set 3 | laguna
# Processing Record 49 of Set 3 | fortuna
# Processing Record 50 of Set 3 | beitbridge
# Processing Record 1 of Set 4 | wanning
# Processing Record 2 of Set 4 | vuktyl
# Processing Record 3 of Set 4 | noumea
# Processing Record 4 of Set 4 | sackville
# Processing Record 5 of Set 4 | krasnotorka
# Processing Record 6 of Set 4 | gat
# Processing Record 7 of Set 4 | port hardy
# Processing Record 8 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 4 | hovd
# Processing Record 10 of Set 4 | airai
# Processing Record 11 of Set 4 | kahului
# Processing Record 12 of Set 4 | antibes
# Processing Record 13 of Set 4 | beringovskiy
# Processing Record 14 of Set 4 | massaguet
# Processing Record 15 of Set 4 | moindou
# Processing Record 16 of Set 4 | tabas
# Processing Record 17 of Set 4 | alekseyevsk
# Processing Record 18 of Set 4 | havoysund
# Processing Record 19 of Set 4 | ancud
# Processing Record 20 of Set 4 | vestmanna
# Processing Record 21 of Set 4 | qaanaaq
# Processing Record 22 of Set 4 | byron bay
# Processing Record 23 of Set 4 | atocha
# Processing Record 24 of Set 4 | castro
# Processing Record 25 of Set 4 | namibe
# Processing Record 26 of Set 4 | vieux-habitants
# Processing Record 27 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 4 | ponta do sol
# Processing Record 29 of Set 4 | new norfolk
# Processing Record 30 of Set 4 | victoria
# Processing Record 31 of Set 4 | anadyr
# Processing Record 32 of Set 4 | takoradi
# Processing Record 33 of Set 4 | la asuncion
# Processing Record 34 of Set 4 | phan thiet
# Processing Record 35 of Set 4 | tuatapere
# Processing Record 36 of Set 4 | seoul
# Processing Record 37 of Set 4 | ystad
# Processing Record 38 of Set 4 | leningradskiy
# Processing Record 39 of Set 4 | puerto madryn
# Processing Record 40 of Set 4 | ferma
# Processing Record 41 of Set 4 | tasiilaq
# Processing Record 42 of Set 4 | banda aceh
# Processing Record 43 of Set 4 | lagoa
# Processing Record 44 of Set 4 | fort morgan
# Processing Record 45 of Set 4 | talakan
# Processing Record 46 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 4 | port macquarie
# Processing Record 48 of Set 4 | kingaroy
# Processing Record 49 of Set 4 | bereda
# Processing Record 50 of Set 4 | brazzaville
# Processing Record 1 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 2 of Set 5 | finschhafen
# Processing Record 3 of Set 5 | pimentel
# Processing Record 4 of Set 5 | boulder city
# Processing Record 5 of Set 5 | tupancireta
# Processing Record 6 of Set 5 | isangel
# Processing Record 7 of Set 5 | hithadhoo
# Processing Record 8 of Set 5 | waipawa
# Processing Record 9 of Set 5 | sao jose da coroa grande
# Processing Record 10 of Set 5 | arroyo
# Processing Record 11 of Set 5 | esperance
# Processing Record 12 of Set 5 | parrita
# Processing Record 13 of Set 5 | camacha
# Processing Record 14 of Set 5 | nizwa
# Processing Record 15 of Set 5 | jedrzejow
# Processing Record 16 of Set 5 | clyde river
# Processing Record 17 of Set 5 | buchanan
# Processing Record 18 of Set 5 | college
# Processing Record 19 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 5 | terney
# Processing Record 21 of Set 5 | port pirie
# Processing Record 22 of Set 5 | tomatlan
# Processing Record 23 of Set 5 | san patricio
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | la ronge
# Processing Record 26 of Set 5 | malakal
# Processing Record 27 of Set 5 | beidao
# Processing Record 28 of Set 5 | mar del plata
# Processing Record 29 of Set 5 | prizren
# Processing Record 30 of Set 5 | norman wells
# Processing Record 31 of Set 5 | chongwe
# Processing Record 32 of Set 5 | saldanha
# Processing Record 33 of Set 5 | mitsamiouli
# Processing Record 34 of Set 5 | scalloway
# City not found. Skipping...
# Processing Record 35 of Set 5 | cap malheureux
# Processing Record 36 of Set 5 | pocao de pedras
# Processing Record 37 of Set 5 | mercedes
# Processing Record 38 of Set 5 | tabou
# Processing Record 39 of Set 5 | kovylkino
# Processing Record 40 of Set 5 | chokurdakh
# Processing Record 41 of Set 5 | veraval
# Processing Record 42 of Set 5 | trelew
# Processing Record 43 of Set 5 | idritsa
# Processing Record 44 of Set 5 | ayan
# Processing Record 45 of Set 5 | kupang
# Processing Record 46 of Set 5 | eureka
# Processing Record 47 of Set 5 | san cristobal
# Processing Record 48 of Set 5 | vestbygda
# City not found. Skipping...
# Processing Record 49 of Set 5 | vardo
# Processing Record 50 of Set 5 | tourlaville
# Processing Record 1 of Set 6 | praia da vitoria
# Processing Record 2 of Set 6 | cape town
# Processing Record 3 of Set 6 | ust-kan
# Processing Record 4 of Set 6 | sandakan
# Processing Record 5 of Set 6 | auki
# Processing Record 6 of Set 6 | carnarvon
# Processing Record 7 of Set 6 | mount hagen
# Processing Record 8 of Set 6 | carutapera
# Processing Record 9 of Set 6 | sao miguel do araguaia
# Processing Record 10 of Set 6 | karratha
# Processing Record 11 of Set 6 | mnogovershinnyy
# Processing Record 12 of Set 6 | fairbanks
# Processing Record 13 of Set 6 | praia
# Processing Record 14 of Set 6 | maputo
# Processing Record 15 of Set 6 | lebu
# Processing Record 16 of Set 6 | souillac
# Processing Record 17 of Set 6 | milkovo
# Processing Record 18 of Set 6 | tabuk
# Processing Record 19 of Set 6 | emborion
# Processing Record 20 of Set 6 | kaitangata
# Processing Record 21 of Set 6 | sarakhs
# Processing Record 22 of Set 6 | port lincoln
# Processing Record 23 of Set 6 | kralendijk
# Processing Record 24 of Set 6 | ust-kuyga
# Processing Record 25 of Set 6 | khotyn
# Processing Record 26 of Set 6 | vangaindrano
# Processing Record 27 of Set 6 | dhidhdhoo
# Processing Record 28 of Set 6 | constitucion
# Processing Record 29 of Set 6 | port elizabeth
# Processing Record 30 of Set 6 | dunedin
# Processing Record 31 of Set 6 | provideniya
# Processing Record 32 of Set 6 | saint-denis
# Processing Record 33 of Set 6 | rio grande
# Processing Record 34 of Set 6 | tautira
# Processing Record 35 of Set 6 | quebec
# Processing Record 36 of Set 6 | tiksi
# Processing Record 37 of Set 6 | los llanos de aridane
# Processing Record 38 of Set 6 | hofn
# Processing Record 39 of Set 6 | kodiak
# Processing Record 40 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 41 of Set 6 | el tigre
# Processing Record 42 of Set 6 | saint-leu
# Processing Record 43 of Set 6 | galveston
# Processing Record 44 of Set 6 | porbandar
# Processing Record 45 of Set 6 | ordynskoye
# Processing Record 46 of Set 6 | bourail
# Processing Record 47 of Set 6 | puerto escondido
# Processing Record 48 of Set 6 | williams lake
# Processing Record 49 of Set 6 | nishihara
# Processing Record 50 of Set 6 | raymond
# Processing Record 1 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 7 | itacurubi del rosario
# Processing Record 3 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 7 | saint-georges
# Processing Record 5 of Set 7 | ambulu
# Processing Record 6 of Set 7 | platanos
# Processing Record 7 of Set 7 | tuktoyaktuk
# Processing Record 8 of Set 7 | srinagar
# Processing Record 9 of Set 7 | plettenberg bay
# Processing Record 10 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 7 | baherden
# Processing Record 12 of Set 7 | vostok
# Processing Record 13 of Set 7 | date
# Processing Record 14 of Set 7 | beeville
# Processing Record 15 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 7 | san ramon
# Processing Record 17 of Set 7 | kerman
# Processing Record 18 of Set 7 | arenys de mar
# Processing Record 19 of Set 7 | dejen
# Processing Record 20 of Set 7 | padang
# Processing Record 21 of Set 7 | marawi
# Processing Record 22 of Set 7 | sapatgram
# Processing Record 23 of Set 7 | nome
# Processing Record 24 of Set 7 | bentiu
# Processing Record 25 of Set 7 | huntingdon
# Processing Record 26 of Set 7 | necochea
# Processing Record 27 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 28 of Set 7 | erenhot
# Processing Record 29 of Set 7 | lata
# Processing Record 30 of Set 7 | helong
# Processing Record 31 of Set 7 | beira
# Processing Record 32 of Set 7 | ariquemes
# Processing Record 33 of Set 7 | avarua
# Processing Record 34 of Set 7 | pisco
# Processing Record 35 of Set 7 | itoman
# Processing Record 36 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 37 of Set 7 | tambaram
# Processing Record 38 of Set 7 | palana
# Processing Record 39 of Set 7 | okhotsk
# Processing Record 40 of Set 7 | torquay
# Processing Record 41 of Set 7 | manggar
# Processing Record 42 of Set 7 | union de san antonio
# Processing Record 43 of Set 7 | sao joao da barra
# Processing Record 44 of Set 7 | tarko-sale
# Processing Record 45 of Set 7 | strezhevoy
# Processing Record 46 of Set 7 | bathsheba
# Processing Record 47 of Set 7 | coahuayana
# Processing Record 48 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 49 of Set 7 | gravelbourg
# Processing Record 50 of Set 7 | ginir
# Processing Record 1 of Set 8 | guerrero negro
# Processing Record 2 of Set 8 | paamiut
# Processing Record 3 of Set 8 | makakilo city
# Processing Record 4 of Set 8 | zharkent
# Processing Record 5 of Set 8 | faya
# Processing Record 6 of Set 8 | flin flon
# Processing Record 7 of Set 8 | smithers
# Processing Record 8 of Set 8 | bengkulu
# Processing Record 9 of Set 8 | ishigaki
# Processing Record 10 of Set 8 | olot
# Processing Record 11 of Set 8 | rawson
# Processing Record 12 of Set 8 | havre-saint-pierre
# Processing Record 13 of Set 8 | saint-augustin
# Processing Record 14 of Set 8 | ahipara
# Processing Record 15 of Set 8 | touros
# Processing Record 16 of Set 8 | meybod
# Processing Record 17 of Set 8 | chingirlau
# Processing Record 18 of Set 8 | guozhen
# Processing Record 19 of Set 8 | nhulunbuy
# Processing Record 20 of Set 8 | aktau
# Processing Record 21 of Set 8 | chik
# Processing Record 22 of Set 8 | shahpura
# Processing Record 23 of Set 8 | waverley
# Processing Record 24 of Set 8 | brae
# Processing Record 25 of Set 8 | fuerte olimpo
# Processing Record 26 of Set 8 | muros
# Processing Record 27 of Set 8 | loveland
# Processing Record 28 of Set 8 | san francisco
# Processing Record 29 of Set 8 | te anau
# Processing Record 30 of Set 8 | herat
# Processing Record 31 of Set 8 | madimba
# Processing Record 32 of Set 8 | shelburne
# Processing Record 33 of Set 8 | lephepe
# City not found. Skipping...
# Processing Record 34 of Set 8 | cabo san lucas
# Processing Record 35 of Set 8 | great bend
# Processing Record 36 of Set 8 | henties bay
# Processing Record 37 of Set 8 | labrea
# Processing Record 38 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 39 of Set 8 | anito
# Processing Record 40 of Set 8 | snyder
# Processing Record 41 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 8 | syava
# Processing Record 43 of Set 8 | san felipe
# Processing Record 44 of Set 8 | oktyabrskoye
# Processing Record 45 of Set 8 | linshu
# City not found. Skipping...
# Processing Record 46 of Set 8 | bambous virieux
# Processing Record 47 of Set 8 | meadow lake
# Processing Record 48 of Set 8 | gibara
# Processing Record 49 of Set 8 | spassk
# Processing Record 50 of Set 8 | coquimbo
# Processing Record 1 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 9 | staroleushkovskaya
# Processing Record 3 of Set 9 | xuddur
# Processing Record 4 of Set 9 | edd
# Processing Record 5 of Set 9 | hami
# Processing Record 6 of Set 9 | moctezuma
# Processing Record 7 of Set 9 | northallerton
# Processing Record 8 of Set 9 | turan
# Processing Record 9 of Set 9 | malchin
# Processing Record 10 of Set 9 | tondano
# Processing Record 11 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 9 | cidreira
# Processing Record 13 of Set 9 | saint george
# Processing Record 14 of Set 9 | broome
# Processing Record 15 of Set 9 | baruun-urt
# Processing Record 16 of Set 9 | voloshka
# Processing Record 17 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 18 of Set 9 | kentau
# Processing Record 19 of Set 9 | chopda
# Processing Record 20 of Set 9 | sandpoint
# Processing Record 21 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 9 | tucuma
# Processing Record 23 of Set 9 | sinnamary
# Processing Record 24 of Set 9 | husavik
# Processing Record 25 of Set 9 | jambi
# Processing Record 26 of Set 9 | tual
# Processing Record 27 of Set 9 | evensk
# Processing Record 28 of Set 9 | san policarpo
# Processing Record 29 of Set 9 | heinola
# Processing Record 30 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 9 | solnechnyy
# Processing Record 33 of Set 9 | kristianstad
# Processing Record 34 of Set 9 | cayenne
# Processing Record 35 of Set 9 | hit
# Processing Record 36 of Set 9 | broken hill
# Processing Record 37 of Set 9 | muncar
# Processing Record 38 of Set 9 | minamata
# Processing Record 39 of Set 9 | onguday
# Processing Record 40 of Set 9 | alofi
# Processing Record 41 of Set 9 | santa isabel
# Processing Record 42 of Set 9 | bend
# Processing Record 43 of Set 9 | korzhevskiy
# Processing Record 44 of Set 9 | soligalich
# Processing Record 45 of Set 9 | ugoofaaru
# Processing Record 46 of Set 9 | northam
# Processing Record 47 of Set 9 | labuhan
# Processing Record 48 of Set 9 | tshikapa
# Processing Record 49 of Set 9 | klaksvik
# Processing Record 50 of Set 9 | port townsend
# Processing Record 1 of Set 10 | hay river
# Processing Record 2 of Set 10 | kyrylivka
# Processing Record 3 of Set 10 | kota
# Processing Record 4 of Set 10 | shahreza
# Processing Record 5 of Set 10 | olovyannaya
# Processing Record 6 of Set 10 | santiago
# Processing Record 7 of Set 10 | tessalit
# Processing Record 8 of Set 10 | mikhaylovka
# Processing Record 9 of Set 10 | jackson
# Processing Record 10 of Set 10 | roald
# Processing Record 11 of Set 10 | soure
# Processing Record 12 of Set 10 | miranda
# Processing Record 13 of Set 10 | port hedland
# Processing Record 14 of Set 10 | inhambane
# Processing Record 15 of Set 10 | englewood
# Processing Record 16 of Set 10 | ahuimanu
# Processing Record 17 of Set 10 | harlingen
# Processing Record 18 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 10 | pangody
# Processing Record 20 of Set 10 | kitob
# Processing Record 21 of Set 10 | richard toll
# City not found. Skipping...
# Processing Record 22 of Set 10 | nisia floresta
# Processing Record 23 of Set 10 | puerto carreno
# Processing Record 24 of Set 10 | puerto del rosario
# Processing Record 25 of Set 10 | grand forks
# Processing Record 26 of Set 10 | ust-maya
# Processing Record 27 of Set 10 | shache
# Processing Record 28 of Set 10 | udachnyy
# Processing Record 29 of Set 10 | lavrentiya
# Processing Record 30 of Set 10 | carbondale
# Processing Record 31 of Set 10 | puteyets
# Processing Record 32 of Set 10 | saint anthony
# Processing Record 33 of Set 10 | shibarghan
# City not found. Skipping...
# Processing Record 34 of Set 10 | mahebourg
# Processing Record 35 of Set 10 | deputatskiy
# Processing Record 36 of Set 10 | pandharpur
# Processing Record 37 of Set 10 | novyy urengoy
# Processing Record 38 of Set 10 | leh
# Processing Record 39 of Set 10 | narsaq
# Processing Record 40 of Set 10 | baltasi
# Processing Record 41 of Set 10 | grottammare
# Processing Record 42 of Set 10 | moyale
# Processing Record 43 of Set 10 | iwanai
# Processing Record 44 of Set 10 | lakes entrance
# Processing Record 45 of Set 10 | bambanglipuro
# Processing Record 46 of Set 10 | vestmannaeyjar
# Processing Record 47 of Set 10 | melipilla
# Processing Record 48 of Set 10 | trincomalee
# Processing Record 49 of Set 10 | sur
# Processing Record 50 of Set 10 | sorrento
# Processing Record 1 of Set 11 | luanda
# Processing Record 2 of Set 11 | kharsawan
# Processing Record 3 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 11 | vao
# Processing Record 5 of Set 11 | kurilsk
# Processing Record 6 of Set 11 | honningsvag
# Processing Record 7 of Set 11 | boa vista
# Processing Record 8 of Set 11 | nuuk
# Processing Record 9 of Set 11 | goure
# Processing Record 10 of Set 11 | jalingo
# Processing Record 11 of Set 11 | fukue
# Processing Record 12 of Set 11 | gornopravdinsk
# Processing Record 13 of Set 11 | kulevcha
# Processing Record 14 of Set 11 | cabildo
# Processing Record 15 of Set 11 | san jose
# Processing Record 16 of Set 11 | prieska
# Processing Record 17 of Set 11 | trelaze
# Processing Record 18 of Set 11 | ketchikan
# Processing Record 19 of Set 11 | khromtau
# Processing Record 20 of Set 11 | chifeng
# Processing Record 21 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 11 | kamenka
# Processing Record 23 of Set 11 | mogadishu
# Processing Record 24 of Set 11 | maromitsa
# Processing Record 25 of Set 11 | huangmei
# Processing Record 26 of Set 11 | cockburn town
# Processing Record 27 of Set 11 | portland
# Processing Record 28 of Set 11 | eyl
# Processing Record 29 of Set 11 | rypefjord
# Processing Record 30 of Set 11 | flinders
# Processing Record 31 of Set 11 | sovetskiy
# Processing Record 32 of Set 11 | dudinka
# Processing Record 33 of Set 11 | hualmay
# Processing Record 34 of Set 11 | lumberton
# Processing Record 35 of Set 11 | vaitape
# Processing Record 36 of Set 11 | dillon
# Processing Record 37 of Set 11 | yenagoa
# Processing Record 38 of Set 11 | asfi
# Processing Record 39 of Set 11 | itaituba
# Processing Record 40 of Set 11 | gorgan
# Processing Record 41 of Set 11 | pevek
# Processing Record 42 of Set 11 | atar
# Processing Record 43 of Set 11 | meulaboh
# Processing Record 44 of Set 11 | alice springs
# Processing Record 45 of Set 11 | maningrida
# Processing Record 46 of Set 11 | geraldton
# Processing Record 47 of Set 11 | antequera
# Processing Record 48 of Set 11 | lorengau
# Processing Record 49 of Set 11 | makueni
# Processing Record 50 of Set 11 | verkhoyansk
# Processing Record 1 of Set 12 | magdalena
# Processing Record 2 of Set 12 | dickinson
# Processing Record 3 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 12 | maceio
# Processing Record 5 of Set 12 | bilaspur
# Processing Record 6 of Set 12 | cocorit
# Processing Record 7 of Set 12 | san vicente de canete
# Processing Record 8 of Set 12 | darnah
# Processing Record 9 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 12 | atakpame
# Processing Record 11 of Set 12 | mountain home
# Processing Record 12 of Set 12 | butajira
# Processing Record 13 of Set 12 | hurricane
# Processing Record 14 of Set 12 | lensk
# Processing Record 15 of Set 12 | salinas
# Processing Record 16 of Set 12 | taywarah
# Processing Record 17 of Set 12 | quelimane
# Processing Record 18 of Set 12 | roscommon
# Processing Record 19 of Set 12 | port-gentil
# Processing Record 20 of Set 12 | arica
# Processing Record 21 of Set 12 | vanimo
# Processing Record 22 of Set 12 | severo-kurilsk
# Processing Record 23 of Set 12 | sainte-maxime
# Processing Record 24 of Set 12 | tongchuan
# Processing Record 25 of Set 12 | estelle
# Processing Record 26 of Set 12 | aleksandrov gay
# Processing Record 27 of Set 12 | north bend
# Processing Record 28 of Set 12 | pangnirtung
# Processing Record 29 of Set 12 | phangnga
# Processing Record 30 of Set 12 | vila
# Processing Record 31 of Set 12 | kimparana
# Processing Record 32 of Set 12 | margate
# Processing Record 33 of Set 12 | kembe
# Processing Record 34 of Set 12 | ewa beach
# Processing Record 35 of Set 12 | tera
# Processing Record 36 of Set 12 | balaka
# Processing Record 37 of Set 12 | waingapu
# Processing Record 38 of Set 12 | bandarbeyla
# Processing Record 39 of Set 12 | fort nelson
# Processing Record 40 of Set 12 | khalkhal
# Processing Record 41 of Set 12 | ankara
# Processing Record 42 of Set 12 | sioux lookout
# Processing Record 43 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 12 | micheweni
# Processing Record 45 of Set 12 | gunjur
# Processing Record 46 of Set 12 | rio gallegos
# Processing Record 47 of Set 12 | arkhipo-osipovka
# Processing Record 48 of Set 12 | lake city
# Processing Record 49 of Set 12 | ballitoville
# Processing Record 50 of Set 12 | slave lake
# Processing Record 1 of Set 13 | caraquet
# Processing Record 2 of Set 13 | sao paulo de olivenca
# Processing Record 3 of Set 13 | qaqortoq
# Processing Record 4 of Set 13 | komsomolskiy
# Processing Record 5 of Set 13 | at-bashi
# Processing Record 6 of Set 13 | loa janan
# Processing Record 7 of Set 13 | saint-pierre
# Processing Record 8 of Set 13 | rexburg
# Processing Record 9 of Set 13 | westport
# Processing Record 10 of Set 13 | soyo
# Processing Record 11 of Set 13 | salina
# Processing Record 12 of Set 13 | sao felix do xingu
# Processing Record 13 of Set 13 | penzance
# Processing Record 14 of Set 13 | brigantine
# Processing Record 15 of Set 13 | hongan
# City not found. Skipping...
# Processing Record 16 of Set 13 | putyatino
# Processing Record 17 of Set 13 | harper
# Processing Record 18 of Set 13 | soe
# Processing Record 19 of Set 13 | bonavista
# Processing Record 20 of Set 13 | fergus falls
# Processing Record 21 of Set 13 | mendahara
# City not found. Skipping...
# Processing Record 22 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 23 of Set 13 | mayumba
# Processing Record 24 of Set 13 | belmonte
# Processing Record 25 of Set 13 | lushunkou
# City not found. Skipping...
# Processing Record 26 of Set 13 | baoding
# Processing Record 27 of Set 13 | angoche
# Processing Record 28 of Set 13 | abu dhabi
# Processing Record 29 of Set 13 | seymchan
# Processing Record 30 of Set 13 | port-cartier
# Processing Record 31 of Set 13 | ust-tsilma
# Processing Record 32 of Set 13 | sao luiz gonzaga
# Processing Record 33 of Set 13 | fare
# Processing Record 34 of Set 13 | santa cruz do rio pardo
# Processing Record 35 of Set 13 | srednekolymsk
# Processing Record 36 of Set 13 | kununurra
# Processing Record 37 of Set 13 | avera
# Processing Record 38 of Set 13 | richmond
# Processing Record 39 of Set 13 | elko
# Processing Record 40 of Set 13 | baykit
# Processing Record 41 of Set 13 | bilma
# Processing Record 42 of Set 13 | kolokani
# Processing Record 43 of Set 13 | kinwat
# Processing Record 44 of Set 13 | cashel
# Processing Record 45 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 46 of Set 13 | jalu
# Processing Record 47 of Set 13 | olinda
# Processing Record 48 of Set 13 | west wendover
# Processing Record 49 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 13 | buraydah
# Processing Record 1 of Set 14 | maltahohe
# Processing Record 2 of Set 14 | clarksdale
# Processing Record 3 of Set 14 | zabol
# Processing Record 4 of Set 14 | puerto varas
# Processing Record 5 of Set 14 | colares
# Processing Record 6 of Set 14 | matagami
# Processing Record 7 of Set 14 | zelenoborskiy
# Processing Record 8 of Set 14 | sosnytsya
# Processing Record 9 of Set 14 | manokwari
# Processing Record 10 of Set 14 | hays
# Processing Record 11 of Set 14 | tokur
# Processing Record 12 of Set 14 | malanje
# Processing Record 13 of Set 14 | wagar
# Processing Record 14 of Set 14 | halifax
# Processing Record 15 of Set 14 | usinsk
# Processing Record 16 of Set 14 | san quintin
# Processing Record 17 of Set 14 | bulle
# Processing Record 18 of Set 14 | pirayu
# Processing Record 19 of Set 14 | panzhihua
# Processing Record 20 of Set 14 | porto novo
# Processing Record 21 of Set 14 | aklavik
# Processing Record 22 of Set 14 | kailua
# Processing Record 23 of Set 14 | vicksburg
# Processing Record 24 of Set 14 | kuching
# Processing Record 25 of Set 14 | yar-sale
# Processing Record 26 of Set 14 | lampazos de naranjo
# Processing Record 27 of Set 14 | springville
# Processing Record 28 of Set 14 | tecoanapa
# Processing Record 29 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 30 of Set 14 | road town
# Processing Record 31 of Set 14 | krasnoarmeysk
# Processing Record 32 of Set 14 | lalmohan
# Processing Record 33 of Set 14 | acarau
# Processing Record 34 of Set 14 | manta
# Processing Record 35 of Set 14 | ejea de los caballeros
# Processing Record 36 of Set 14 | humaita
# Processing Record 37 of Set 14 | potosi
# Processing Record 38 of Set 14 | almaznyy
# Processing Record 39 of Set 14 | kisesa
# Processing Record 40 of Set 14 | okaihau
# Processing Record 41 of Set 14 | elat
# Processing Record 42 of Set 14 | davila
# Processing Record 43 of Set 14 | sanary-sur-mer
# Processing Record 44 of Set 14 | metairie
# Processing Record 45 of Set 14 | nyurba
# Processing Record 46 of Set 14 | bagdarin
# Processing Record 47 of Set 14 | bumba
# Processing Record 48 of Set 14 | zaigrayevo
# Processing Record 49 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 14 | proddatur
# Processing Record 1 of Set 15 | kuryk
# Processing Record 2 of Set 15 | richards bay
# Processing Record 3 of Set 15 | yevlax
# Processing Record 4 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 15 | betki
# City not found. Skipping...
# Processing Record 6 of Set 15 | saint-medard-en-jalles
# Processing Record 7 of Set 15 | vila franca do campo
# Processing Record 8 of Set 15 | abha
# Processing Record 9 of Set 15 | itapua poty
# City not found. Skipping...
# Processing Record 10 of Set 15 | kavaratti
# Processing Record 11 of Set 15 | pamplona
# Processing Record 12 of Set 15 | lisakovsk
# Processing Record 13 of Set 15 | kanalion
# Processing Record 14 of Set 15 | tobane
# Processing Record 15 of Set 15 | ravar
# Processing Record 16 of Set 15 | young
# Processing Record 17 of Set 15 | leonidion
# City not found. Skipping...
# Processing Record 18 of Set 15 | new amsterdam
# Processing Record 19 of Set 15 | kieta
# Processing Record 20 of Set 15 | motatei
# Processing Record 21 of Set 15 | kabugao
# Processing Record 22 of Set 15 | diffa
# Processing Record 23 of Set 15 | rudnyy
# Processing Record 24 of Set 15 | nadym
# Processing Record 25 of Set 15 | washington
# Processing Record 26 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 15 | brokopondo
# Processing Record 28 of Set 15 | sorland
# Processing Record 29 of Set 15 | mandalgovi
# Processing Record 30 of Set 15 | ola
# Processing Record 31 of Set 15 | voh
# Processing Record 32 of Set 15 | faro
# Processing Record 33 of Set 15 | buala
# Processing Record 34 of Set 15 | tanabe
# Processing Record 35 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 36 of Set 15 | lubartow
# Processing Record 37 of Set 15 | kibala
# Processing Record 38 of Set 15 | ibra
# Processing Record 39 of Set 15 | santa rosa
# Processing Record 40 of Set 15 | ixtapa
# Processing Record 41 of Set 15 | leshukonskoye
# Processing Record 42 of Set 15 | hirara
# Processing Record 43 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 44 of Set 15 | cascais
# Processing Record 45 of Set 15 | aswan
# Processing Record 46 of Set 15 | daura
# Processing Record 47 of Set 15 | celestun
# Processing Record 48 of Set 15 | opuwo
# Processing Record 49 of Set 15 | alpena
# Processing Record 50 of Set 15 | gazanjyk
# Processing Record 1 of Set 16 | roma
# Processing Record 2 of Set 16 | sangar
# Processing Record 3 of Set 16 | poya
# Processing Record 4 of Set 16 | bairiki
# Processing Record 5 of Set 16 | matara
# Processing Record 6 of Set 16 | whittlesea
# Processing Record 7 of Set 16 | vengerovo
# Processing Record 8 of Set 16 | pechora
# Processing Record 9 of Set 16 | chapais
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Ilulissat      GL  69.2167  -51.1000     -9.40        45
# 1            Jamestown      US  42.0970  -79.2353     62.60        39
# 2               Albany      US  42.6001  -73.9662     57.00        45
# 3                 Sola      VU -13.8833  167.5500     84.20        79
# 4         Puerto Ayora      EC  -0.7393  -90.3518     82.40        74
# 5         Kruisfontein      ZA -34.0033   24.7314     59.00        77
# 6  Huejuquilla El Alto      MX  22.6000 -103.8667     82.63         4
# 7               Bozoum      CF   6.3193   16.3799     76.03        57
# 8             Freeport      US  40.6576  -73.5832     59.00        58
# 9               Yulara      AU -25.2406  130.9889     73.40        73
#
#    Cloudiness  Wind Speed  Current Weather
# 0          20        3.44       few clouds
# 1           1        8.61        clear sky
# 2          76        6.17    broken clouds
# 3          75        5.75    broken clouds
# 4          20       11.50       few clouds
# 5           1        1.01        clear sky
# 6          89       17.67  overcast clouds
# 7          74        2.89       light rain
# 8           1       16.11        clear sky
# 9         100        5.75  overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
